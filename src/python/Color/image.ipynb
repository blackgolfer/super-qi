# %% [markdown]
# # On Image Colors
#
# Reference:
# 1. [Colour Filtering and Colour Pop Effects using OpenCV Python](https://medium.com/featurepreneur/colour-filtering-and-colour-pop-effects-using-opencv-python-3ce7d4576140)
# 2. [Building an Image Color Analyzer using Python](https://towardsdatascience.com/building-an-image-color-analyzer-using-python-12de6b0acf74)
# 3. [Image Color Extraction with Python in 4 Steps](https://towardsdatascience.com/image-color-extraction-with-python-in-4-steps-8d9370d9216e)

# %% [markdown]
# ## Color filtering

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import hsv_to_rgb

#read the image
img = cv.imread("images/flower.jpg")
plt.axis('off')
plt.imshow(img)

# %%
from Color.Plot import hsv_imshow

# %%
#convert the BGR image to HSV colour space
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

hsv_imshow(hsv)

# %%
#set the lower and upper bounds for the green hue
lower_green = np.array([50,100,50])
upper_green = np.array([70,255,255])

#create a mask for green colour using inRange function
mask = cv.inRange(hsv, lower_green, upper_green)

#perform bitwise and on the original image arrays using the mask
res = cv.bitwise_and(img, img, mask=mask)

hsv_imshow(mask)

# %%
hsv_imshow(res)

# %%
def prep_image(raw_img,size):
    modified_img = cv.resize(raw_img,size,interpolation=cv.INTER_AREA)
    modified_img = modified_img.reshape(modified_img.shape[0]*modified_img.shape[1], 3)
    return modified_img

# %%
hsv_img=prep_image(hsv,(900,900))
