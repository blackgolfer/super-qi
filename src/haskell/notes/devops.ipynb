# %% [markdown]
# # The Haskell Development Environment

# %% [markdown]
# ## Package management
# References:
# - [Packages](https://ghc.gitlab.haskell.org/ghc/doc/users_guide/packages.html#package-databases)

# %%
ghc-pkg list
# Out:
# /nix/store/75h2sskifkr54yv1kgf2z6jx3ijr29b7-ghc-9.2.4-with-packages/lib/ghc-9.2.4/package.conf.d
#     Boolean-0.2.4
#     Cabal-3.6.3.0
#     Chart-1.9.4
#     Chart-cairo-1.9.3
#     JuicyPixels-3.3.7
#     MemoTrie-0.6.10
#     MonadPrompt-1.0.0.5
#     MonadRandom-0.5.3
#     NumInstances-1.4
#     OneTuple-0.3.1
#     QuickCheck-2.14.2
#     StateVar-1.2.2
#     active-0.2.0.16
#     adjunctions-4.4.2
#     aeson-2.0.3.0
#     aeson-pretty-0.8.9
#     ansi-terminal-0.11.4
#     ansi-wl-pprint-0.6.9
#     appar-0.1.8
#     array-0.5.4.0
#     asn1-encoding-0.9.6
#     asn1-parse-0.9.5
#     asn1-types-0.3.4
#     assoc-1.0.2
#     async-2.2.4
#     attoparsec-0.14.4
#     z-attoparsec-z-attoparsec-internal-0.14.4
#     base-4.16.3.0
#     base-compat-0.12.2
#     base-compat-batteries-0.12.2
#     base-orphans-0.8.7
#     base64-bytestring-1.2.1.0
#     basement-0.0.15
#     bifunctors-5.5.14
#     binary-0.8.9.0
#     binary-orphans-1.0.3
#     blaze-builder-0.4.2.2
# ...
